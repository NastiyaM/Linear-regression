# %%
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Datasets

# %%
# generate dataset
X, y = datasets.make_regression(n_samples=1_000, n_features=1, noise=10,shuffle=True)

# %%
plt.figure(figsize=(15, 15))
plt.subplot(2, 1, 1)
plt.title("Линейная модель") # заголовок
plt.xlabel("x") # ось абсцисс
plt.ylabel("y") # ось ординат
plt.grid()
plt.scatter(X, y, color='red', s=10)
plt.show()

# %% [markdown]
# # Linear Regression Scikit-learn

# %% [markdown]
# # Training and predictions

# %%
# test and train data sizes
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# create linear regression object
regr = linear_model.LinearRegression()

# train the model using the training sets
regr.fit(X_train, y_train)

# make predictions using the testing set
y_pred = regr.predict(X_test)

# %% [markdown]
# # Graph Plotting

# %%
# plot outputs
plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.title("Линейная модель") # заголовок
plt.xlabel("x") # ось абсцисс
plt.ylabel("y") # ось ординат
plt.grid()
plt.scatter(X_test, y_test, color='red', s=10)
plt.plot(X_test, y_pred, color='blue', linewidth=1)
plt.show()

# %% [markdown]
# # Metrics

# %%
rmse = mean_squared_error(y_test, y_pred)
print('rmse',rmse)
r2 = r2_score(y_test, y_pred)
print('r2',r2)
# Out:
# rmse 104.4702690529709
# r2 0.988315043132289

# %% [markdown]
# # Linear Model

# %%
from matplotlib import pyplot as plt
from celluloid import Camera

# %%
class LinearRegressionUsingGD:
    """Linear Regression Using Gradient Descent.
    Parameters
    ----------
    eta : float
        Learning rate
    n_iterations : int
        No of passes over the training set
    Attributes
    ----------
    w_ : weights/ after fitting the model
    cost_ : total error of the model after each iteration
    """

    def __init__(self, eta=0.05, n_iterations=1000,n = 50):
        self.eta = eta
        self.n_iterations = n_iterations
        self.n = n
    def predict(self, x):
        """ Predicts the value after the model has been trained.
        Parameters
        ----------
        x : array-like, shape = [n_samples, n_features]
            Test samples
        Returns
        -------
        Predicted value
        """
        return np.dot(x, self.w_)

    def fit(self, x, y,X_test,X_test_,y_test):
        """Fit the training data
        Parameters
        ----------
        x : array-like, shape = [n_samples, n_features]
            Training samples
        y : array-like, shape = [n_samples, n_target_values]
            Target values
        Returns
        -------
        self : object
        """

        self.cost_ = []
        self.w_ = np.zeros((x.shape[1], 1))
        m = x.shape[0]
        fig = plt.figure()
        camera = Camera(fig)
        
        for _ in range(self.n):
            y_pred = np.dot(x, self.w_)
            residuals = y_pred - y
            gradient_vector = np.dot(x.T, residuals)
            self.w_ -= (self.eta / m) * gradient_vector
            cost = np.sum((residuals ** 2)) / (2 * m)
            self.cost_.append(cost)
            y_pred =self.predict(X_test)
            plt.title("Линейная модель") # заголовок
            plt.xlabel("x") # ось абсцисс
            plt.ylabel("y") # ось ординат
            plt.grid()
            plt.scatter(X_test_, y_test, color='red', s=10)
            t = plt.plot(X_test_, y_pred, color='blue', linewidth=1)
            plt.legend(t, [f'iteration{_}'])
            camera.snap()
        animation = camera.animate()
        animation.save('celluloid_legends.gif', writer='imagemagick')
        return self
    def fit_(self, x, y):
        """Fit the training data
        Parameters
        ----------
        x : array-like, shape = [n_samples, n_features]
            Training samples
        y : array-like, shape = [n_samples, n_target_values]
            Target values
        Returns
        -------
        self : object
        """

        self.cost_ = []
        self.w_ = np.zeros((x.shape[1], 1))
        m = x.shape[0]
        for _ in range(self.n_iterations):
            y_pred = np.dot(x, self.w_)
            residuals = y_pred - y
            gradient_vector = np.dot(x.T, residuals)
            self.w_ -= (self.eta / m) * gradient_vector
            cost = np.sum((residuals ** 2)) / (2 * m)
            self.cost_.append(cost)
        return self

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

X_train, X_test_, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train = np.c_[np.ones((len(X_train), 1)),X_train]
X_test = np.c_[np.ones((len(X_test_), 1)),X_test_]
# split the targets into training/testing sets
y_train = y_train.reshape(len(y_train),1)
linear_regression_model = LinearRegressionUsingGD()

# %% [markdown]
# # GIF

# %%
# fit/train the model
linear_regression_model.fit(X_train, y_train,X_test,X_test_,y_test)

# %%
y_pred_ = linear_regression_model.predict(X_test)

# %%
rmse = mean_squared_error(y_test, y_pred_)
print('rmse',rmse)
r2 = r2_score(y_test, y_pred_)
print('r2',r2)
# Out:
# rmse 158.70453071936097
# r2 0.9822489631454308

# %% [markdown]
# # Training and predictions

# %%
linear_regression_model.fit_(X_train, y_train)
y_pred_ = linear_regression_model.predict(X_test)

# %% [markdown]
# # Graph Plotting

# %%
plt.figure(figsize=(15, 15))
plt.subplot(2, 1, 1)
plt.title("Линейная модель") # заголовок
plt.xlabel("x") # ось абсцисс
plt.ylabel("y") # ось ординат
plt.grid()
plt.scatter(X_test_, y_test, color='red', s=10)
plt.plot(X_test_, y_pred_, color='blue', linewidth=1)
plt.show()

# %% [markdown]
# # Metrics

# %%
rmse = mean_squared_error(y_test, y_pred_)
print('rmse',rmse)
r2 = r2_score(y_test, y_pred_)
print('r2',r2)
# Out:
# rmse 104.47026905297112
# r2 0.988315043132289

# %% [markdown]
# # Multiple linear regression

# %%
X, y = datasets.make_regression(n_samples=1_000, n_features=2, noise=10,shuffle=True)

# %%
import pylab
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import axes3d
import numpy

def makeData():
    x1 = [X[i][0] for i in range(0,len(X))] 
    x2 = [X[i][1] for i in range(0,len(X))] 
    z = y
    return x1, x2, z

x_, y_, z_ = makeData()

axes = axes3d.Axes3D(plt.figure(figsize=(10,10)))
axes.scatter(x_, y_, z_, c = 'red')
pylab.show()

# %% [markdown]
# # Training and predictions

# %%
# test and train data sizes
train_size = 800 
test_size = 200

# split the data into training/testing sets
X_train = X[:train_size]
X_test = X[train_size:]

# split the targets into training/testing sets
y_train = y[:train_size]
y_test = y[train_size:]

# create linear regression object
regr = linear_model.LinearRegression()

# train the model using the training sets
regr.fit(X_train, y_train)

# make predictions using the testing set
y_pred = regr.predict(X_test)

# %% [markdown]
# # Metrics

# %%
rmse = mean_squared_error(y_test, y_pred)
print('rmse',rmse)
r2 = r2_score(y_test, y_pred)
print('r2',r2)
# Out:
# rmse 101.90882944278488
# r2 0.9711056965143849

# %% [markdown]
# # Graph Plotting

# %%
import pylab
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import axes3d
import numpy

def makeData_ ():
    x1 = [X_test[i][0] for i in range(0,len(X_test))] 
    x2 = [X_test[i][1] for i in range(0,len(X_test))] 
    y = y_test
    return x1, x2, y
def makeData():
    x1 = [X_test[i][0] for i in range(0,len(X_test))] 
    x2 = [X_test[i][1] for i in range(0,len(X_test))] 
    y = y_pred 
    return x1, x2, y

x, y1, z = makeData_()
x_, y1_, z_ = makeData()

#fig = pylab.figure()
axes = axes3d.Axes3D(plt.figure(figsize=(10,10)))
#axes = Axes3D(fig)
axes.scatter(x, y1, z, c = 'red')
axes.scatter(x_, y1_, z_,alpha = .15)
axes.plot_trisurf(x_, y1_, z_,alpha=.10)
pylab.show()

# %% [markdown]
# # Polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
import math

# %%
x,y = datasets.make_regression(n_samples=1_000, n_features=1, noise=10,shuffle=True)
#x = np.arange(30)
y = -5*np.sin(x) + 10*np.cos(x) + x -x**2 + x**3 -x**5

# %%
plt.figure(figsize=(15, 15))
plt.subplot(2, 1, 1)
plt.title("Линейная модель") # заголовок
plt.xlabel("x") # ось абсцисс
plt.ylabel("y") # ось ординат
plt.grid()
plt.scatter(x, y, color='red', s=10)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
#X_test= X_test.sort()
#X_train= X_train.sort()
def pol_ragr(deg):
    model = PolynomialFeatures(degree=deg)
    X_train_transform = model.fit_transform(X_train[:, np.newaxis])
    pol_reg = linear_model.LinearRegression()
    pol_reg.fit(X_train_transform, y_train)
    X_test_transform = model.fit_transform(X_test[:, np.newaxis])
    y_pred = pol_reg.predict(X_test_transform)
    score = pol_reg.score(X_test_transform, y_test)
    rmse = mean_squared_error(y_test, y_pred)
    print('rmse',rmse)
    r2 = r2_score(y_test, y_pred)
    print('r2',r2)
    plt.figure(figsize=(15, 15))
    plt.subplot(2, 1, 1)
    plt.title("Линейная модель") # заголовок
    plt.xlabel("x") # ось абсцисс
    plt.ylabel("y") # ось ординат
    plt.grid()
    plt.scatter(X_test, y_test,color='red', s=20)
    plt.scatter(X_test, y_pred,label='degree ' + str(deg), s=20)
    plt.legend(loc=2)
    plt.show()

# %%
from matplotlib import pyplot as plt
import time
from celluloid import Camera
fig = plt.figure()
camera = Camera(fig)
for deg in range(1,20):
    model = PolynomialFeatures(degree=deg)
    X_train_transform = model.fit_transform(X_train)
    pol_reg = linear_model.LinearRegression()
    pol_reg.fit(X_train_transform, y_train)
    X_test_transform = model.fit_transform(X_test)
    y_pred = pol_reg.predict(X_test_transform)
    score = pol_reg.score(X_test_transform, y_test)
    plt.title("Линейная модель") # заголовок
    plt.xlabel("x") # ось абсцисс
    plt.ylabel("y") # ось ординат
    plt.scatter(X_test, y_pred,color = 'black',s =20)
    plt.legend([f'\n degree = {deg}\n \n R^2 = {r2_score(y_test, y_pred)}'])
    plt.scatter(X_test, y_test,color='red', s=20)
    #t = plt.scatter(X_test, y_pred, s=20)
    camera.snap()
    plt.title("Линейная модель") # заголовок
    plt.xlabel("x") # ось абсцисс
    plt.ylabel("y") # ось ординат
    plt.grid()
    plt.scatter(X_test, y_pred,color = 'black',s =20)
    plt.legend([f'\n degree = {deg}\n \n R^2 = {r2_score(y_test, y_pred)}'])
    plt.scatter(X_test, y_test,color='red', s=20)
    #t = plt.scatter(X_test, y_pred, s=20)
    camera.snap()
    plt.title("Линейная модель") # заголовок
    plt.xlabel("x") # ось абсцисс
    plt.ylabel("y") # ось ординат
    plt.grid()
    plt.scatter(X_test, y_pred,color = 'black',s =20)
    plt.legend([f'\n degree = {deg}\n \n R^2 = {r2_score(y_test, y_pred)}'])
    plt.scatter(X_test, y_test,color='red', s=20)
    #t = plt.scatter(X_test, y_pred, s=20)
    camera.snap()
    plt.title("Линейная модель") # заголовок
    plt.xlabel("x") # ось абсцисс
    plt.ylabel("y") # ось ординат
    plt.grid()
    plt.scatter(X_test, y_pred,color = 'black',s =20)
    plt.legend([f'\n degree = {deg}\n \n R^2 = {r2_score(y_test, y_pred)}'])
    plt.scatter(X_test, y_test,color='red', s=20)
    #t = plt.scatter(X_test, y_pred, s=20)
    camera.snap()
animation = camera.animate()
animation.save('pol_regr.gif', writer='imagemagick')
